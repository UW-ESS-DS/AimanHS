# %% [markdown]
# This new notebook will allow me to plot random data made by Aiman Shamsul 09/29/23

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.random.rand(10)
print(a)
# Out:
# [0.04552303 0.25377353 0.88166283 0.14308427 0.71700246 0.65236913
#  0.26099987 0.35269644 0.21719489 0.39431869]

# %%
plt.plot(a)
plt.xlabel('Time (s)')
plt.grid(True)
plt.savefig("toto.png")
